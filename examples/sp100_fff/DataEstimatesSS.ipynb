# %% [markdown]
# # S&P 100 Data Estimates - Single Stock

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import datetime as dt
import quandl

# %% [markdown]
# ## Data

# %%
datadir='../../data/'
assets=pd.read_csv(datadir + 'SP100.csv', comment='#').set_index('Symbol')
QUANDL={
    'authtoken':"6XyApK2BBj_MraQg2TMD",
    'start_date':dt.date(2016, 1, 1),
    'end_date':dt.date(2018, 12, 31)
}
RISK_FREE_SYMBOL = "USDOLLAR"
data={}

# %% [markdown]
# #### Download loop

# %% [markdown]
# If it stops because of Quandl error codes 503 or 504, try re-running it (it won't download data already downloaded). If Quandl complains about the speed of requests, try adding sleep time.

# %%
# Download assets' data
from time import sleep

def to_quandl_eod_ticker(ticker):
    '''
    Converts ticker to format in Quandl EOD dataset
    '''
    if 'USDOLLAR' not in ticker:
        return 'EOD/' + ticker.replace('.', '_')
    else:
        return 'FRED/DTB3'

# Construct a data dictionary: {ticker: pd.DataFrame(price/volume)}
for ticker in assets.index:
    if ticker in data:
        continue
    print('downloading %s from %s to %s' %(ticker, QUANDL['start_date'], QUANDL['end_date']))
    try:
        data[ticker] = quandl.get(to_quandl_eod_ticker(ticker), **QUANDL)
    except quandl.NotFoundError:
        print('\tInvalid asset code')
# Out:
# downloading AAPL from 2016-01-01 to 2018-12-31
# downloading ABBV from 2016-01-01 to 2018-12-31
# downloading ABT from 2016-01-01 to 2018-12-31
# downloading ACN from 2016-01-01 to 2018-12-31
# downloading ADBE from 2016-01-01 to 2018-12-31
# downloading AGN from 2016-01-01 to 2018-12-31
# downloading AIG from 2016-01-01 to 2018-12-31
# downloading ALL from 2016-01-01 to 2018-12-31
# downloading AMGN from 2016-01-01 to 2018-12-31
# downloading AMZN from 2016-01-01 to 2018-12-31
# downloading AXP from 2016-01-01 to 2018-12-31
# downloading BA from 2016-01-01 to 2018-12-31
# downloading BAC from 2016-01-01 to 2018-12-31
# downloading BIIB from 2016-01-01 to 2018-12-31
# downloading BK from 2016-01-01 to 2018-12-31
# downloading BKNG from 2016-01-01 to 2018-12-31
# downloading BLK from 2016-01-01 to 2018-12-31
# downloading BMY from 2016-01-01 to 2018-12-31
# downloading BRK.B from 2016-01-01 to 2018-12-31
# downloading C from 2016-01-01 to 2018-12-31
# downloading CAT from 2016-01-01 to 2018-12-31
# downloading CELG from 2016-01-01 to 2018-12-31
# downloading CHTR from 2016-01-01 to 2018-12-31
# downloading CL from 2016-01-01 to 2018-12-31
# downloading CMCSA from 2016-01-01 to 2018-12-31
# downloading COF from 2016-01-01 to 2018-12-31
# downloading COP from 2016-01-01 to 2018-12-31
# downloading COST from 2016-01-01 to 2018-12-31
# downloading CSCO from 2016-01-01 to 2018-12-31
# downloading CVS from 2016-01-01 to 2018-12-31
# downloading CVX from 2016-01-01 to 2018-12-31
# downloading DD from 2016-01-01 to 2018-12-31
# downloading DHR from 2016-01-01 to 2018-12-31
# downloading DIS from 2016-01-01 to 2018-12-31
# downloading DOW from 2016-01-01 to 2018-12-31
# downloading DUK from 2016-01-01 to 2018-12-31
# downloading EMR from 2016-01-01 to 2018-12-31
# downloading EXC from 2016-01-01 to 2018-12-31
# downloading F from 2016-01-01 to 2018-12-31
# downloading FB from 2016-01-01 to 2018-12-31
# downloading FDX from 2016-01-01 to 2018-12-31
# downloading GD from 2016-01-01 to 2018-12-31
# downloading GE from 2016-01-01 to 2018-12-31
# downloading GILD from 2016-01-01 to 2018-12-31
# downloading GM from 2016-01-01 to 2018-12-31
# downloading GOOG from 2016-01-01 to 2018-12-31
# downloading GOOGL from 2016-01-01 to 2018-12-31
# downloading GS from 2016-01-01 to 2018-12-31
# downloading HD from 2016-01-01 to 2018-12-31
# downloading HON from 2016-01-01 to 2018-12-31
# downloading IBM from 2016-01-01 to 2018-12-31
# downloading INTC from 2016-01-01 to 2018-12-31
# downloading JNJ from 2016-01-01 to 2018-12-31
# downloading JPM from 2016-01-01 to 2018-12-31
# downloading KHC from 2016-01-01 to 2018-12-31
# downloading KMI from 2016-01-01 to 2018-12-31
# downloading KO from 2016-01-01 to 2018-12-31
# downloading LLY from 2016-01-01 to 2018-12-31
# downloading LMT from 2016-01-01 to 2018-12-31
# downloading LOW from 2016-01-01 to 2018-12-31
# downloading MA from 2016-01-01 to 2018-12-31
# downloading MCD from 2016-01-01 to 2018-12-31
# downloading MDLZ from 2016-01-01 to 2018-12-31
# downloading MDT from 2016-01-01 to 2018-12-31
# downloading MET from 2016-01-01 to 2018-12-31
# downloading MMM from 2016-01-01 to 2018-12-31
# downloading MO from 2016-01-01 to 2018-12-31
# downloading MRK from 2016-01-01 to 2018-12-31
# downloading MS from 2016-01-01 to 2018-12-31
# downloading MSFT from 2016-01-01 to 2018-12-31
# downloading NEE from 2016-01-01 to 2018-12-31
# downloading NFLX from 2016-01-01 to 2018-12-31
# downloading NKE from 2016-01-01 to 2018-12-31
# downloading NVDA from 2016-01-01 to 2018-12-31
# downloading ORCL from 2016-01-01 to 2018-12-31
# downloading OXY from 2016-01-01 to 2018-12-31
# downloading PEP from 2016-01-01 to 2018-12-31
# downloading PFE from 2016-01-01 to 2018-12-31
# downloading PG from 2016-01-01 to 2018-12-31
# downloading PM from 2016-01-01 to 2018-12-31
# downloading PYPL from 2016-01-01 to 2018-12-31
# downloading QCOM from 2016-01-01 to 2018-12-31
# downloading RTN from 2016-01-01 to 2018-12-31
# downloading SBUX from 2016-01-01 to 2018-12-31
# downloading SLB from 2016-01-01 to 2018-12-31
# downloading SO from 2016-01-01 to 2018-12-31
# downloading SPG from 2016-01-01 to 2018-12-31
# downloading T from 2016-01-01 to 2018-12-31
# downloading TGT from 2016-01-01 to 2018-12-31
# downloading TXN from 2016-01-01 to 2018-12-31
# downloading UNH from 2016-01-01 to 2018-12-31
# downloading UNP from 2016-01-01 to 2018-12-31
# downloading UPS from 2016-01-01 to 2018-12-31
# downloading USB from 2016-01-01 to 2018-12-31
# downloading UTX from 2016-01-01 to 2018-12-31
# downloading V from 2016-01-01 to 2018-12-31
# downloading VZ from 2016-01-01 to 2018-12-31
# downloading WBA from 2016-01-01 to 2018-12-31
# downloading WFC from 2016-01-01 to 2018-12-31
# downloading WMT from 2016-01-01 to 2018-12-31
# downloading XOM from 2016-01-01 to 2018-12-31
# downloading USDOLLAR from 2016-01-01 to 2018-12-31

# %% [markdown]
# #### Computation

# %%
keys=[el for el in assets.index if not el in (set(assets.index)-set(data.keys()))]

def select_first_valid_column(df, columns):
    for column in columns:
        if column in df.columns:
            return df[column]

# extract prices
prices=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Adj. Close", "Close", "Value"])
                                              for k in keys])))

#compute sigmas
open_price=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Open"]) for k in keys])))
close_price=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Close"]) for k in keys])))
sigmas = np.abs(np.log(open_price.astype(float))-np.log(close_price.astype(float)))

# extract volumes
volumes=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Adj. Volume", "Volume"])
                                               for k in keys])))

# fix risk free
prices[RISK_FREE_SYMBOL]=10000*(1 + prices[RISK_FREE_SYMBOL]/(100*250)).cumprod()

# %% [markdown]
# #### Filtering

# %%
# filter NaNs - threshold at 2% missing values
bad_assets = prices.columns[prices.isnull().sum()>len(prices)*0.02]
if len(bad_assets):
    print('Assets %s have too many NaNs, removing them' % bad_assets)

prices = prices.loc[:,~prices.columns.isin(bad_assets)]
sigmas = sigmas.loc[:,~sigmas.columns.isin(bad_assets)]
volumes = volumes.loc[:,~volumes.columns.isin(bad_assets)]

nassets=prices.shape[1]

# days on which many assets have missing values
bad_days1=sigmas.index[sigmas.isnull().sum(1) > nassets*.9]
bad_days2=prices.index[prices.isnull().sum(1) > nassets*.9]
bad_days3=volumes.index[volumes.isnull().sum(1) > nassets*.9]
bad_days=pd.Index(set(bad_days1).union(set(bad_days2)).union(set(bad_days3))).sort_values()
print ("Removing these days from dataset:")
print(pd.DataFrame({'nan price':prices.isnull().sum(1)[bad_days],
                    'nan volumes':volumes.isnull().sum(1)[bad_days],
                    'nan sigmas':sigmas.isnull().sum(1)[bad_days]}))

prices=prices.loc[~prices.index.isin(bad_days)]
sigmas=sigmas.loc[~sigmas.index.isin(bad_days)]
volumes=volumes.loc[~volumes.index.isin(bad_days)]

# extra filtering
print(pd.DataFrame({'remaining nan price':prices.isnull().sum(),
                    'remaining nan volumes':volumes.isnull().sum(),
                    'remaining nan sigmas':sigmas.isnull().sum()}))
prices=prices.fillna(method='ffill')
sigmas=sigmas.fillna(method='ffill')
volumes=volumes.fillna(method='ffill')
print(pd.DataFrame({'remaining nan price':prices.isnull().sum(),
                    'remaining nan volumes':volumes.isnull().sum(),
                    'remaining nan sigmas':sigmas.isnull().sum()}))
# Out:
# Assets Index(['DD', 'DOW'], dtype='object') have too many NaNs, removing them
# Removing these days from dataset:
# Empty DataFrame
# Columns: [nan price, nan volumes, nan sigmas]
# Index: []
#           remaining nan price  remaining nan volumes  remaining nan sigmas
# AAPL                        0                      0                     0
# ABBV                        0                      0                     0
# ABT                         0                      0                     0
# ACN                         0                      0                     0
# ADBE                        0                      0                     0
# ...                       ...                    ...                   ...
# WBA                         0                      0                     0
# WFC                         0                      0                     0
# WMT                         0                      0                     0
# XOM                         0                      0                     0
# USDOLLAR                    5                    754                   754
#
# [100 rows x 3 columns]
#           remaining nan price  remaining nan volumes  remaining nan sigmas
# AAPL                        0                      0                     0
# ABBV                        0                      0                     0
# ABT                         0                      0                     0
# ACN                         0                      0                     0
# ADBE                        0                      0                     0
# ...                       ...                    ...                   ...
# WBA                         0                      0                     0
# WFC                         0                      0                     0
# WMT                         0                      0                     0
# XOM                         0                      0                     0
# USDOLLAR                    0                    754                   754
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Save

# %%
# make volumes in dollars
volumes = volumes*prices

# compute returns
returns = (prices.diff()/prices.shift(1)).fillna(method='ffill').iloc[1:]

bad_assets = returns.columns[((-.5>returns).sum()>0)|((returns > 2.).sum()>0)]
if len(bad_assets):
    print('Assets %s have dubious returns, removed' % bad_assets)
    
prices = prices.loc[:,~prices.columns.isin(bad_assets)]
sigmas = sigmas.loc[:,~sigmas.columns.isin(bad_assets)]
volumes = volumes.loc[:,~volumes.columns.isin(bad_assets)]
returns = returns.loc[:,~returns.columns.isin(bad_assets)]

# remove USDOLLAR except from returns
prices = prices.iloc[:,:-1]
sigmas = sigmas.iloc[:,:-1]
volumes = volumes.iloc[:,:-1]


# save data
prices.to_csv(datadir+'ss_prices.csv.gz', compression='gzip', float_format='%.3f')
volumes.to_csv(datadir+'ss_volumes.csv.gz', compression='gzip', float_format='%d')
returns.to_csv(datadir+'ss_returns.csv.gz', compression='gzip', float_format='%.3e')
sigmas.to_csv(datadir+'ss_sigmas.csv.gz', compression='gzip', float_format='%.3e')

# %% [markdown]
# ## Estimates

# %%
print("Typical variance of returns: %g"%returns.var().mean())
# Out:
# Typical variance of returns: 0.000212859

# %%
return_estimate = returns.ewm(alpha=0.1, min_periods=60).mean().shift(1).dropna()
return_estimate
# Out:
#                 AAPL      ABBV       ABT       ACN      ADBE       AGN  \
# Date
# 2016-04-01  0.004391  0.001582  0.003592  0.006434  0.004440 -0.004225
# 2016-04-04  0.004870  0.001949  0.004094  0.006614  0.005448 -0.003779
# 2016-04-05  0.005412  0.004876  0.003993  0.005220  0.004208  0.000133
# 2016-04-06  0.003689  0.003255  0.002930  0.003510  0.003437 -0.014672
# 2016-04-07  0.004368  0.005238  0.005042  0.003632  0.004400 -0.009736
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-24 -0.012618 -0.002135 -0.004665 -0.012557 -0.011248 -0.012788
# 2018-12-26 -0.013943 -0.002817 -0.006741 -0.013875 -0.011867 -0.012757
# 2018-12-27 -0.005507  0.003263  0.000126 -0.008492 -0.002009 -0.008716
# 2018-12-28 -0.005605  0.003914  0.001564 -0.006636 -0.000826 -0.008399
# 2018-12-31 -0.004993  0.004868  0.002059 -0.006392 -0.001636 -0.007461
#
#                  AIG       ALL      AMGN      AMZN  ...       UPS       USB  \
# Date                                                ...
# 2016-04-01  0.001798  0.001986  0.001931  0.004005  ...  0.002473  0.000073
# 2016-04-04  0.003174  0.003066  0.004564  0.004424  ...  0.001732  0.000337
# 2016-04-05  0.001962  0.001893  0.004432  0.003093  ...  0.001491  0.000254
# 2016-04-06  0.000441  0.000312  0.002881  0.001593  ...  0.000425 -0.001322
# 2016-04-07  0.001198  0.000776  0.006985  0.004156  ...  0.001105 -0.001090
# ...              ...       ...       ...       ...  ...       ...       ...
# 2018-12-24 -0.005177 -0.004688 -0.006634 -0.013953  ... -0.009042 -0.011244
# 2018-12-26 -0.004846 -0.007450 -0.006975 -0.014989  ... -0.011999 -0.012025
# 2018-12-27 -0.000986 -0.002136 -0.000974 -0.004045  ... -0.003323 -0.007098
# 2018-12-28  0.001030 -0.000698  0.000438 -0.004270  ... -0.001780 -0.005815
# 2018-12-31 -0.000878 -0.000347  0.000604 -0.002722  ... -0.002880 -0.006197
#
#                  UTX         V        VZ       WBA       WFC       WMT  \
# Date
# 2016-04-01  0.002533  0.004065  0.002306  0.002850 -0.001636  0.001376
# 2016-04-04  0.002149  0.005112  0.001945  0.005490 -0.001286  0.002072
# 2016-04-05  0.002234  0.004910  0.002511  0.004490 -0.001054  0.001922
# 2016-04-06  0.001601  0.003312  0.001652  0.000618 -0.002992  0.001063
# 2016-04-07  0.001952  0.004593  0.000432  0.000952 -0.001492  0.001540
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-24 -0.011280 -0.008541 -0.004143 -0.015411 -0.008003 -0.006828
# 2018-12-26 -0.014032 -0.009723 -0.007134 -0.016843 -0.010572 -0.007648
# 2018-12-27 -0.008759 -0.001768 -0.003800 -0.011389 -0.004950 -0.001535
# 2018-12-28 -0.008119 -0.000224 -0.002116 -0.009305 -0.004587 -0.000076
# 2018-12-31 -0.007704 -0.001013 -0.001687 -0.008828 -0.003579  0.000521
#
#                  XOM  USDOLLAR
# Date
# 2016-04-01  0.000375  0.000011
# 2016-04-04 -0.000418  0.000011
# 2016-04-05 -0.000134  0.000011
# 2016-04-06 -0.001265  0.000011
# 2016-04-07  0.000201  0.000010
# ...              ...       ...
# 2018-12-24 -0.010032  0.000093
# 2018-12-26 -0.012860  0.000094
# 2018-12-27 -0.006796  0.000094
# 2018-12-28 -0.005679  0.000094
# 2018-12-31 -0.006228  0.000094
#
# [693 rows x 100 columns]

# %%
agree_on_sign=np.sign(returns.iloc[60:,:-1]) == np.sign(return_estimate.iloc[:,:-1])
print("Return predictions have the right sign %.1f%% of the times"%
      (100*agree_on_sign.sum().sum()/(agree_on_sign.shape[0]*(agree_on_sign.shape[1]-1))))
# Out:
# Return predictions have the right sign 50.1% of the times

# %%
volume_estimate=volumes.ewm(alpha=0.1, min_periods=60).mean().dropna()
volume_estimate.to_csv(datadir+'ss_volume_estimate.csv.gz', compression='gzip', float_format='%d')
sigma_estimate = returns.ewm(alpha=0.1, min_periods=60).cov().dropna()
sigma_estimate.to_csv(datadir+'ss_sigma_estimate.csv.gz', compression='gzip', float_format='%.3e')
return_estimate.to_hdf(datadir+'ss_model.h5', 'return_estimate')
volume_estimate.to_hdf(datadir+'ss_model.h5', 'volume_estimate')
sigma_estimate.to_hdf(datadir+'ss_model.h5', 'sigma_estimate')
