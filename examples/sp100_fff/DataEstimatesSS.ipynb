# %% [markdown]
# # S&P 100 Data Estimates - Single Stock

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import datetime as dt
import quandl

# %% [markdown]
# ## Data

# %%
datadir='../../data/'
assets=pd.read_csv(datadir + 'SP100.csv', comment='#').set_index('Symbol')
QUANDL={
    'authtoken':"6XyApK2BBj_MraQg2TMD",
    'start_date':dt.date(2017, 1, 2),
    'end_date':dt.date(2018, 12, 31)
}
RISK_FREE_SYMBOL = "USDOLLAR"
data={}

# %% [markdown]
# #### Download loop

# %% [markdown]
# If it stops because of Quandl error codes 503 or 504, try re-running it (it won't download data already downloaded). If Quandl complains about the speed of requests, try adding sleep time.

# %%
# Download assets' data
from time import sleep

def to_quandl_eod_ticker(ticker):
    '''
    Converts ticker to format in Quandl EOD dataset
    '''
    if 'USDOLLAR' not in ticker:
        return 'EOD/' + ticker.replace('.', '_')
    else:
        return 'FRED/DTB3'

# Construct a data dictionary: {ticker: pd.DataFrame(price/volume)}
for ticker in assets.index:
    if ticker in data:
        continue
    print('downloading %s from %s to %s' %(ticker, QUANDL['start_date'], QUANDL['end_date']))
    try:
        data[ticker] = quandl.get(to_quandl_eod_ticker(ticker), **QUANDL)
    except quandl.NotFoundError:
        print('\tInvalid asset code')
# Out:
# downloading AAPL from 2017-01-02 to 2018-12-31
# downloading ABBV from 2017-01-02 to 2018-12-31
# downloading ABT from 2017-01-02 to 2018-12-31
# downloading ACN from 2017-01-02 to 2018-12-31
# downloading ADBE from 2017-01-02 to 2018-12-31
# downloading AGN from 2017-01-02 to 2018-12-31
# downloading AIG from 2017-01-02 to 2018-12-31
# downloading ALL from 2017-01-02 to 2018-12-31
# downloading AMGN from 2017-01-02 to 2018-12-31
# downloading AMZN from 2017-01-02 to 2018-12-31
# downloading AXP from 2017-01-02 to 2018-12-31
# downloading BA from 2017-01-02 to 2018-12-31
# downloading BAC from 2017-01-02 to 2018-12-31
# downloading BIIB from 2017-01-02 to 2018-12-31
# downloading BK from 2017-01-02 to 2018-12-31
# downloading BKNG from 2017-01-02 to 2018-12-31
# downloading BLK from 2017-01-02 to 2018-12-31
# downloading BMY from 2017-01-02 to 2018-12-31
# downloading BRK.B from 2017-01-02 to 2018-12-31
# downloading C from 2017-01-02 to 2018-12-31
# downloading CAT from 2017-01-02 to 2018-12-31
# downloading CELG from 2017-01-02 to 2018-12-31
# downloading CHTR from 2017-01-02 to 2018-12-31
# downloading CL from 2017-01-02 to 2018-12-31
# downloading CMCSA from 2017-01-02 to 2018-12-31
# downloading COF from 2017-01-02 to 2018-12-31
# downloading COP from 2017-01-02 to 2018-12-31
# downloading COST from 2017-01-02 to 2018-12-31
# downloading CSCO from 2017-01-02 to 2018-12-31
# downloading CVS from 2017-01-02 to 2018-12-31
# downloading CVX from 2017-01-02 to 2018-12-31
# downloading DD from 2017-01-02 to 2018-12-31
# downloading DHR from 2017-01-02 to 2018-12-31
# downloading DIS from 2017-01-02 to 2018-12-31
# downloading DOW from 2017-01-02 to 2018-12-31
# downloading DUK from 2017-01-02 to 2018-12-31
# downloading EMR from 2017-01-02 to 2018-12-31
# downloading EXC from 2017-01-02 to 2018-12-31
# downloading F from 2017-01-02 to 2018-12-31
# downloading FB from 2017-01-02 to 2018-12-31
# downloading FDX from 2017-01-02 to 2018-12-31
# downloading GD from 2017-01-02 to 2018-12-31
# downloading GE from 2017-01-02 to 2018-12-31
# downloading GILD from 2017-01-02 to 2018-12-31
# downloading GM from 2017-01-02 to 2018-12-31
# downloading GOOG from 2017-01-02 to 2018-12-31
# downloading GOOGL from 2017-01-02 to 2018-12-31
# downloading GS from 2017-01-02 to 2018-12-31
# downloading HD from 2017-01-02 to 2018-12-31
# downloading HON from 2017-01-02 to 2018-12-31
# downloading IBM from 2017-01-02 to 2018-12-31
# downloading INTC from 2017-01-02 to 2018-12-31
# downloading JNJ from 2017-01-02 to 2018-12-31
# downloading JPM from 2017-01-02 to 2018-12-31
# downloading KHC from 2017-01-02 to 2018-12-31
# downloading KMI from 2017-01-02 to 2018-12-31
# downloading KO from 2017-01-02 to 2018-12-31
# downloading LLY from 2017-01-02 to 2018-12-31
# downloading LMT from 2017-01-02 to 2018-12-31
# downloading LOW from 2017-01-02 to 2018-12-31
# downloading MA from 2017-01-02 to 2018-12-31
# downloading MCD from 2017-01-02 to 2018-12-31
# downloading MDLZ from 2017-01-02 to 2018-12-31
# downloading MDT from 2017-01-02 to 2018-12-31
# downloading MET from 2017-01-02 to 2018-12-31
# downloading MMM from 2017-01-02 to 2018-12-31
# downloading MO from 2017-01-02 to 2018-12-31
# downloading MRK from 2017-01-02 to 2018-12-31
# downloading MS from 2017-01-02 to 2018-12-31
# downloading MSFT from 2017-01-02 to 2018-12-31
# downloading NEE from 2017-01-02 to 2018-12-31
# downloading NFLX from 2017-01-02 to 2018-12-31
# downloading NKE from 2017-01-02 to 2018-12-31
# downloading NVDA from 2017-01-02 to 2018-12-31
# downloading ORCL from 2017-01-02 to 2018-12-31
# downloading OXY from 2017-01-02 to 2018-12-31
# downloading PEP from 2017-01-02 to 2018-12-31
# downloading PFE from 2017-01-02 to 2018-12-31
# downloading PG from 2017-01-02 to 2018-12-31
# downloading PM from 2017-01-02 to 2018-12-31
# downloading PYPL from 2017-01-02 to 2018-12-31
# downloading QCOM from 2017-01-02 to 2018-12-31
# downloading RTN from 2017-01-02 to 2018-12-31
# downloading SBUX from 2017-01-02 to 2018-12-31
# downloading SLB from 2017-01-02 to 2018-12-31
# downloading SO from 2017-01-02 to 2018-12-31
# downloading SPG from 2017-01-02 to 2018-12-31
# downloading T from 2017-01-02 to 2018-12-31
# downloading TGT from 2017-01-02 to 2018-12-31
# downloading TXN from 2017-01-02 to 2018-12-31
# downloading UNH from 2017-01-02 to 2018-12-31
# downloading UNP from 2017-01-02 to 2018-12-31
# downloading UPS from 2017-01-02 to 2018-12-31
# downloading USB from 2017-01-02 to 2018-12-31
# downloading UTX from 2017-01-02 to 2018-12-31
# downloading V from 2017-01-02 to 2018-12-31
# downloading VZ from 2017-01-02 to 2018-12-31
# downloading WBA from 2017-01-02 to 2018-12-31
# downloading WFC from 2017-01-02 to 2018-12-31
# downloading WMT from 2017-01-02 to 2018-12-31
# downloading XOM from 2017-01-02 to 2018-12-31
# downloading USDOLLAR from 2017-01-02 to 2018-12-31

# %% [markdown]
# #### Computation

# %%
keys=[el for el in assets.index if not el in (set(assets.index)-set(data.keys()))]

def select_first_valid_column(df, columns):
    for column in columns:
        if column in df.columns:
            return df[column]

# extract prices
prices=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Adj. Close", "Close", "Value"])
                                              for k in keys])))

#compute sigmas
open_price=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Open"]) for k in keys])))
close_price=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Close"]) for k in keys])))
sigmas = np.abs(np.log(open_price.astype(float))-np.log(close_price.astype(float)))

# extract volumes
volumes=pd.DataFrame.from_dict(dict(zip(keys, [select_first_valid_column(data[k], ["Adj. Volume", "Volume"])
                                               for k in keys])))

# fix risk free
prices[RISK_FREE_SYMBOL]=10000*(1 + prices[RISK_FREE_SYMBOL]/(100*250)).cumprod()

# %% [markdown]
# #### Filtering

# %%
# filter NaNs - threshold at 2% missing values
bad_assets = prices.columns[prices.isnull().sum()>len(prices)*0.02]
if len(bad_assets):
    print('Assets %s have too many NaNs, removing them' % bad_assets)

prices = prices.loc[:,~prices.columns.isin(bad_assets)]
sigmas = sigmas.loc[:,~sigmas.columns.isin(bad_assets)]
volumes = volumes.loc[:,~volumes.columns.isin(bad_assets)]

nassets=prices.shape[1]

# days on which many assets have missing values
bad_days1=sigmas.index[sigmas.isnull().sum(1) > nassets*.9]
bad_days2=prices.index[prices.isnull().sum(1) > nassets*.9]
bad_days3=volumes.index[volumes.isnull().sum(1) > nassets*.9]
bad_days=pd.Index(set(bad_days1).union(set(bad_days2)).union(set(bad_days3))).sort_values()
print ("Removing these days from dataset:")
print(pd.DataFrame({'nan price':prices.isnull().sum(1)[bad_days],
                    'nan volumes':volumes.isnull().sum(1)[bad_days],
                    'nan sigmas':sigmas.isnull().sum(1)[bad_days]}))

prices=prices.loc[~prices.index.isin(bad_days)]
sigmas=sigmas.loc[~sigmas.index.isin(bad_days)]
volumes=volumes.loc[~volumes.index.isin(bad_days)]

# extra filtering
print(pd.DataFrame({'remaining nan price':prices.isnull().sum(),
                    'remaining nan volumes':volumes.isnull().sum(),
                    'remaining nan sigmas':sigmas.isnull().sum()}))
prices=prices.fillna(method='ffill')
sigmas=sigmas.fillna(method='ffill')
volumes=volumes.fillna(method='ffill')
print(pd.DataFrame({'remaining nan price':prices.isnull().sum(),
                    'remaining nan volumes':volumes.isnull().sum(),
                    'remaining nan sigmas':sigmas.isnull().sum()}))
# Out:
# Assets Index(['DD', 'DOW'], dtype='object') have too many NaNs, removing them
# Removing these days from dataset:
# Empty DataFrame
# Columns: [nan price, nan volumes, nan sigmas]
# Index: []
#           remaining nan price  remaining nan volumes  remaining nan sigmas
# AAPL                        0                      0                     0
# ABBV                        0                      0                     0
# ABT                         0                      0                     0
# ACN                         0                      0                     0
# ADBE                        0                      0                     0
# ...                       ...                    ...                   ...
# WBA                         0                      0                     0
# WFC                         0                      0                     0
# WMT                         0                      0                     0
# XOM                         0                      0                     0
# USDOLLAR                    3                    502                   502
#
# [100 rows x 3 columns]
#           remaining nan price  remaining nan volumes  remaining nan sigmas
# AAPL                        0                      0                     0
# ABBV                        0                      0                     0
# ABT                         0                      0                     0
# ACN                         0                      0                     0
# ADBE                        0                      0                     0
# ...                       ...                    ...                   ...
# WBA                         0                      0                     0
# WFC                         0                      0                     0
# WMT                         0                      0                     0
# XOM                         0                      0                     0
# USDOLLAR                    0                    502                   502
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Save

# %%
# make volumes in dollars
volumes = volumes*prices

# compute returns
returns = (prices.diff()/prices.shift(1)).fillna(method='ffill').iloc[1:]

bad_assets = returns.columns[((-.5>returns).sum()>0)|((returns > 2.).sum()>0)]
if len(bad_assets):
    print('Assets %s have dubious returns, removed' % bad_assets)
    
prices = prices.loc[:,~prices.columns.isin(bad_assets)]
sigmas = sigmas.loc[:,~sigmas.columns.isin(bad_assets)]
volumes = volumes.loc[:,~volumes.columns.isin(bad_assets)]
returns = returns.loc[:,~returns.columns.isin(bad_assets)]

# remove USDOLLAR except from returns
prices = prices.iloc[:,:-1]
sigmas = sigmas.iloc[:,:-1]
volumes = volumes.iloc[:,:-1]


# save data
prices.to_csv(datadir+'ss_prices.csv.gz', compression='gzip', float_format='%.3f')
volumes.to_csv(datadir+'ss_volumes.csv.gz', compression='gzip', float_format='%d')
returns.to_csv(datadir+'ss_returns.csv.gz', compression='gzip', float_format='%.3e')
sigmas.to_csv(datadir+'ss_sigmas.csv.gz', compression='gzip', float_format='%.3e')

# %% [markdown]
# ## Estimates

# %%
print("Typical variance of returns: %g"%returns.var().mean())
# Out:
# Typical variance of returns: 0.000205843

# %%
return_estimate = returns.ewm(alpha=0.1, min_periods=60).mean().shift(1).dropna()
return_estimate
# Out:
#                 AAPL      ABBV       ABT       ACN      ADBE       AGN  \
# Date
# 2017-03-31  0.002700  0.000630 -0.000594 -0.001365  0.004031  0.000344
# 2017-04-03  0.002242  0.000108 -0.000849 -0.001760  0.004029 -0.000058
# 2017-04-04  0.002045 -0.000103 -0.000629 -0.003455  0.003210 -0.000572
# 2017-04-05  0.002586  0.000031 -0.001219 -0.002769  0.003236 -0.000199
# 2017-04-06  0.001808 -0.000203 -0.001958 -0.002831  0.002797 -0.000456
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-24 -0.012618 -0.002135 -0.004665 -0.012557 -0.011248 -0.012788
# 2018-12-26 -0.013943 -0.002817 -0.006741 -0.013875 -0.011867 -0.012757
# 2018-12-27 -0.005507  0.003263  0.000126 -0.008492 -0.002009 -0.008716
# 2018-12-28 -0.005605  0.003914  0.001564 -0.006636 -0.000826 -0.008399
# 2018-12-31 -0.004993  0.004868  0.002059 -0.006392 -0.001636 -0.007461
#
#                  AIG       ALL      AMGN      AMZN  ...       UPS       USB  \
# Date                                                ...
# 2017-03-31  0.000434  0.000220 -0.003267  0.002952  ...  0.000244 -0.002623
# 2017-04-03  0.000166  0.000014 -0.003128  0.003822  ...  0.000821 -0.003552
# 2017-04-04 -0.000877 -0.000196 -0.002925  0.004001  ... -0.000102 -0.003099
# 2017-04-05 -0.000157  0.000205 -0.002345  0.005321  ...  0.000125 -0.002963
# 2017-04-06 -0.001043 -0.000073 -0.003402  0.005059  ...  0.000216 -0.003484
# ...              ...       ...       ...       ...  ...       ...       ...
# 2018-12-24 -0.005177 -0.004688 -0.006634 -0.013953  ... -0.009042 -0.011244
# 2018-12-26 -0.004846 -0.007450 -0.006975 -0.014989  ... -0.011999 -0.012025
# 2018-12-27 -0.000986 -0.002136 -0.000974 -0.004045  ... -0.003323 -0.007098
# 2018-12-28  0.001030 -0.000698  0.000438 -0.004270  ... -0.001780 -0.005815
# 2018-12-31 -0.000878 -0.000347  0.000604 -0.002722  ... -0.002880 -0.006197
#
#                  UTX             V        VZ       WBA       WFC       WMT  \
# Date
# 2017-03-31  0.000219  1.753553e-04 -0.001105 -0.001223 -0.001127  0.002185
# 2017-04-03 -0.000017  2.508829e-07 -0.001628 -0.001413 -0.002047  0.002652
# 2017-04-04 -0.000265  5.523967e-04 -0.000581 -0.001392 -0.002148  0.002039
# 2017-04-05  0.000710 -1.528269e-04 -0.000258 -0.001796 -0.002456  0.002086
# 2017-04-06  0.000204  1.444012e-04 -0.000821 -0.003230 -0.002609  0.001376
# ...              ...           ...       ...       ...       ...       ...
# 2018-12-24 -0.011280 -8.541049e-03 -0.004143 -0.015411 -0.008003 -0.006828
# 2018-12-26 -0.014032 -9.722997e-03 -0.007134 -0.016843 -0.010572 -0.007648
# 2018-12-27 -0.008759 -1.768031e-03 -0.003800 -0.011389 -0.004950 -0.001535
# 2018-12-28 -0.008119 -2.244154e-04 -0.002116 -0.009305 -0.004587 -0.000076
# 2018-12-31 -0.007704 -1.012519e-03 -0.001687 -0.008828 -0.003579  0.000521
#
#                  XOM  USDOLLAR
# Date
# 2017-03-31  0.002251  0.000029
# 2017-04-03  0.000004  0.000029
# 2017-04-04  0.000077  0.000029
# 2017-04-05  0.000435  0.000030
# 2017-04-06  0.000586  0.000030
# ...              ...       ...
# 2018-12-24 -0.010032  0.000093
# 2018-12-26 -0.012860  0.000094
# 2018-12-27 -0.006796  0.000094
# 2018-12-28 -0.005679  0.000094
# 2018-12-31 -0.006228  0.000094
#
# [441 rows x 100 columns]

# %%
agree_on_sign=np.sign(returns.iloc[60:,:-1]) == np.sign(return_estimate.iloc[:,:-1])
print("Return predictions have the right sign %.1f%% of the times"%
      (100*agree_on_sign.sum().sum()/(agree_on_sign.shape[0]*(agree_on_sign.shape[1]-1))))
# Out:
# Return predictions have the right sign 50.6% of the times

# %%
volume_estimate=volumes.ewm(alpha=0.1, min_periods=60).mean().shift(1).dropna()
volume_estimate.to_csv(datadir+'ss_volume_estimate.csv.gz', compression='gzip', float_format='%d')
sigma_estimate = returns.ewm(alpha=0.1, min_periods=60).cov().dropna()
sigma_estimate.to_csv(datadir+'ss_sigma_estimate.csv.gz', compression='gzip', float_format='%.3e')
return_estimate.to_hdf(datadir+'ss_model.h5', 'return_estimate')
volume_estimate.to_hdf(datadir+'ss_model.h5', 'volume_estimate')
sigma_estimate.to_hdf(datadir+'ss_model.h5', 'sigma_estimate')
